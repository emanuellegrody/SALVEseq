# %%
import sys
# !{sys.executable} -m pip install singletCode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from singletCode import check_sample_sheet, get_singlets

# %%
import pandas as pd
df = pd.read_csv("/projects/b1042/GoyalLab/egrody/extractedData/EGS024/barcode/stepThree/GFP_barcode_1/stepThreeStarcodeShavedReads.txt", sep="\t")
df = df.rename(columns={"BC50StarcodeD8": "barcode"})
df["sample"] = "GFP_barcode_1"
df = df[["cellID", "barcode", "sample"]]

cellLabelList, stats = get_singlets(df, dataset_name = "GFP_barcode_1", 
                                    output_path = "/projects/b1042/GoyalLab/egrody/extractedData/EGS024/barcode/singletCode/",
                                   save_all_singlet_categories = True,
                                   save_plot_umi = True
                                   )
# Out:
# INFO: Raw data counts:
# sample
# GFP_barcode_1    326409
# Name: count, dtype: int64
# Total cells for sample GFP_barcode_1: 9889
# INFO: Using ratio based filtering.
# Current Sample Adjusted UMI cutoff: 2
# 100%|██████████| 27251/27251 [00:01<00:00, 25054.55it/s]
# All singlets identified with multiple barcodes are unique? True
# Total Singlets: 5483
# Total Multiplets: 3279

# %%
df = pd.read_csv("/projects/b1042/GoyalLab/egrody/extractedData/EGS024/barcode/stepThree/GFP_barcode_9/stepThreeStarcodeShavedReads.txt", sep="\t")
df = df.rename(columns={"BC50StarcodeD8": "barcode"})
df["sample"] = "GFP_barcode_9"
df = df[["cellID", "barcode", "sample"]]

cellLabelList, stats = get_singlets(df, dataset_name = "GFP_barcode_9", 
                                    output_path = "/projects/b1042/GoyalLab/egrody/extractedData/EGS024/barcode/singletCode/",
                                   save_all_singlet_categories = True,
                                   save_plot_umi = True
                                   )
# Out:
# INFO: Raw data counts:
# sample
# GFP_barcode_9    295891
# Name: count, dtype: int64
# Total cells for sample GFP_barcode_9: 9973
# INFO: Using ratio based filtering.
# Current Sample Adjusted UMI cutoff: 2
# 100%|██████████| 26083/26083 [00:01<00:00, 25084.12it/s]
# All singlets identified with multiple barcodes are unique? True
# Total Singlets: 5791
# Total Multiplets: 3229
